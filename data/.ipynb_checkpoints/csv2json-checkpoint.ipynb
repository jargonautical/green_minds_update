# %%
import pandas as pd
import json
import pprint
pp = pprint.PrettyPrinter(indent=4)
input_data = "network_entries.csv"
df = pd.read_csv(input_data)
df.head(1)
# Out:
#   pid    project_name   latitude  longitude  \
# 0  n1  The Data Place  50.369333  -4.139171
#
#                                                notes  \
# 0   Social enterprise that hosts Plymouth's netwo...
#
#                           url    contact_name          contact_email  \
# 0   https://www.thedata.place   Martin Howitt   martin@thedata.place
#
#    Unnamed: 8 id2
# 0         NaN  n1

# %%
def csv2json(csvFile, jsonFile):
    import csv
    import json
    # create an empty list
    out_list = []
    out_dict = {}
    # open the csv file
    with open('network_entries.csv') as file_obj:
        # Create reader object by passing the file object to reader method
        reader_obj = csv.reader(file_obj)
        # Iterate over each row in the csv file using reader objec
        for row in reader_obj:
            row_dict = {}
            row_dict["pid"] = row[0]
            row_dict["pname"] = row[1]
            row_dict["lat"] = row[2]
            row_dict["lon"] = row[3]
            row_dict["notes"] = row[4]
            out_list.append(row_dict)
        out_dict[row_dict["pid"] = out_list
        
    pp.pprint(out_list)
    with open(jsonFile,"w") as f:
        json.dump(out_list,f)

# assign values in the row to variables

# create an empty dictionary

# push the variables to a dictionary

# append the dictionary to the list

csv2json('network_entries.csv', 'test2.json')
# Out:
# [   {   'n1': {   'lat': '50.36933301',
#                   'lon': '-4.13917106',
#                   'notes': " Social enterprise that hosts Plymouth's network "
#                            'map and associated green space data tools.',
#                   'pid': 'n1',
#                   'pname': 'The Data Place'},
#         'n10': {   'lat': '50.38545648',
#                    'lon': '-4.15150386',
#                    'notes': 'Cafe and landmark in the middle of Central Park ',
#                    'pid': 'n10',
#                    'pname': 'Meadow Cafe Central Park'},
#         'n11': {   'lat': '50.37534061',
#                    'lon': '-4.12424773',
#                    'notes': ' Tools and creative resources to support your '
#                             'connection to the natural world and to your inner '
#                             'ecosystem ',
#                    'pid': 'n11',
#                    'pname': 'SeaWyld'},
#         'n12': {   'lat': '50.40799787',
# ...

# %%
import csv
import json
 
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows['id2']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    #with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
    #    jsonf.write(json.dumps(data, indent=4))
        
    with open(jsonFilePath,"w") as f:
        json.dump(data,f)
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'network_entries.csv'
jsonFilePath = r'network_entries5.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %%
# to file as lines
with open('temp.json', 'w') as f:
    f.write(df.to_json(orient='records', lines=True))

# %%
list_dict = []

for index, row in list(df.iterrows()):
    list_dict.append(dict(row))

with open("output.json", 'w') as f:
    f.write("\n".join(str(item) for item in list_dict))

# %%
out_json = {}
out_list = []
for i in df.iterrows():
    print(i)
# Out:
# (0, project_name                                        The Data Place
# latitude                                                 50.369333
# longitude                                                -4.139171
# notes             Social enterprise that hosts Plymouth's netwo...
# url                                      https://www.thedata.place
# contact_name                                         Martin Howitt
# contact_email                                 martin@thedata.place
# Name: 0, dtype: object)
# (1, project_name                                     Family tree field
# latitude                                                 50.386495
# longitude                                                -4.148714
# notes             Plymouth Tree Partnership maintain records fo...
# url                                 https://www.plymouthtrees.org/
# contact_name                                         Martin Howitt
# contact_email                               martin@datahatch.co.uk
# ...

# %%
result = df.to_json(orient="index")
parsed = json.loads(result)
#json.dumps(parsed, indent=4)  
#pp.pprint(parsed)

# %%
f = open("network3.json", "a")
f.write(result)
f.close()

# %%
output_file = {}

pname = [x for x in df['Project name']]
